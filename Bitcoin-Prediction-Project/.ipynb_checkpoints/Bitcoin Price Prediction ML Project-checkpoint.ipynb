# %%
# installations

# Install yfinance inside the JupyterLab environment
import sys
# !{sys.executable} -m pip install yfinance --upgrade --use-pep517

# Installation of pandas_ta
# !pip install pandas_ta
# Out:
# Requirement already satisfied: yfinance in c:\users\aneli\anaconda3\lib\site-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\aneli\anaconda3\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\aneli\anaconda3\lib\site-packages (from yfinance) (2.2.6)
# Requirement already satisfied: requests>=2.31 in c:\users\aneli\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\aneli\anaconda3\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\aneli\anaconda3\lib\site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in c:\users\aneli\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\aneli\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\aneli\anaconda3\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\aneli\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\aneli\anaconda3\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\aneli\anaconda3\lib\site-packages (from yfinance) (5.29.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\aneli\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aneli\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\aneli\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\aneli\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.6.15)
# Requirement already satisfied: pycparser in c:\users\aneli\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aneli\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aneli\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\aneli\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aneli\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aneli\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aneli\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: pandas_ta in c:\users\aneli\anaconda3\lib\site-packages (0.4.71b0)
# Requirement already satisfied: numba==0.61.2 in c:\users\aneli\anaconda3\lib\site-packages (from pandas_ta) (0.61.2)
# Requirement already satisfied: numpy>=2.2.6 in c:\users\aneli\anaconda3\lib\site-packages (from pandas_ta) (2.2.6)
# Requirement already satisfied: pandas>=2.3.2 in c:\users\aneli\anaconda3\lib\site-packages (from pandas_ta) (2.3.3)
# Requirement already satisfied: tqdm>=4.67.1 in c:\users\aneli\anaconda3\lib\site-packages (from pandas_ta) (4.67.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\aneli\anaconda3\lib\site-packages (from numba==0.61.2->pandas_ta) (0.44.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aneli\anaconda3\lib\site-packages (from pandas>=2.3.2->pandas_ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aneli\anaconda3\lib\site-packages (from pandas>=2.3.2->pandas_ta) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aneli\anaconda3\lib\site-packages (from pandas>=2.3.2->pandas_ta) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\aneli\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.3.2->pandas_ta) (1.17.0)
# Requirement already satisfied: colorama in c:\users\aneli\anaconda3\lib\site-packages (from tqdm>=4.67.1->pandas_ta) (0.4.6)

# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sn

import yfinance as yf
import pandas_ta as ta

from sklearn.preprocessing import MinMaxScaler

import scipy.stats as stats
from scipy.stats import spearmanr
from scipy.stats import kendalltau
from sklearn.feature_selection import mutual_info_regression

from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# # Predicting Bitcoin Prices Using Machine Learning

# %% [markdown]
# ## Introduction / Abstract

# %% [markdown]
# Given historical Bitcoin price data, can we predict the price for the next few days?

# %% [markdown]
# ## Dataset & Preprocessing

# %%
# Read the Kaggle dataset containing Bitcoin historical data
btc_data = pd.read_csv("data/btcusd_1-min_data.csv")

# %%
btc_data
# Out:
#             Timestamp       Open       High        Low      Close    Volume
# 0        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 1        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 2        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 3        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 4        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# ...               ...        ...        ...        ...        ...       ...
# 7251512  1.760572e+09  110716.00  110740.00  110716.00  110740.00  6.220424
# 7251513  1.760572e+09  110740.00  110740.00  110716.00  110716.00  3.255152
# 7251514  1.760572e+09  110716.00  110717.00  110716.00  110717.00  5.158200
# 7251515  1.760573e+09  110716.00  110740.00  110716.00  110740.00  1.173851
# 7251516  1.760573e+09  110740.00  110763.00  110740.00  110763.00  1.370955
#
# [7251517 rows x 6 columns]

# %%
# Convert timestamp to datetime
btc_data['Timestamp'] = pd.to_datetime(btc_data['Timestamp'], unit='s')

# %%
btc_data.tail()
# Out:
#                   Timestamp      Open      High       Low     Close    Volume
# 7251512 2025-10-15 23:53:00  110716.0  110740.0  110716.0  110740.0  6.220424
# 7251513 2025-10-15 23:54:00  110740.0  110740.0  110716.0  110716.0  3.255152
# 7251514 2025-10-15 23:55:00  110716.0  110717.0  110716.0  110717.0  5.158200
# 7251515 2025-10-15 23:56:00  110716.0  110740.0  110716.0  110740.0  1.173851
# 7251516 2025-10-15 23:57:00  110740.0  110763.0  110740.0  110763.0  1.370955

# %%
btc_data.set_index('Timestamp', inplace=True)

# %%
# btc_data = btc_data.resample('1D')

# %%
# Daily resampling
btc_data_daily = btc_data.resample('1D').agg({
    'Open': 'first',
    'High': 'max',
    'Low': 'min',
    'Close': 'last',
    'Volume': 'sum'
})

# %%
btc_data[btc_data.index.astype(str).str.startswith("2025-10-15 00:00:00")].describe()
# Out:
#            Open      High       Low     Close    Volume
# count       1.0       1.0       1.0       1.0  1.000000
# mean   113077.0  113091.0  113041.0  113081.0  0.874398
# std         NaN       NaN       NaN       NaN       NaN
# min    113077.0  113091.0  113041.0  113081.0  0.874398
# 25%    113077.0  113091.0  113041.0  113081.0  0.874398
# 50%    113077.0  113091.0  113041.0  113081.0  0.874398
# 75%    113077.0  113091.0  113041.0  113081.0  0.874398
# max    113077.0  113091.0  113041.0  113081.0  0.874398

# %%
btc_data_daily.tail()
# Out:
#                 Open      High       Low     Close       Volume
# Timestamp
# 2025-10-11  112989.0  113444.0  109711.0  110764.0  2954.913907
# 2025-10-12  110769.0  115854.0  109711.0  115090.0  2969.343862
# 2025-10-13  115089.0  116035.0  113751.0  115265.0  1947.580681
# 2025-10-14  115275.0  115508.0  109971.0  113078.0  2253.667329
# 2025-10-15  113077.0  113655.0  110217.0  110763.0  2021.923209

# %%
# Shape of the daily BTC dataset
btc_data_daily.shape
# Out:
# (5037, 5)

# %% [markdown]
# Now there are much less records that is why some additional measurements will be included.

# %%
# Although the dataset seems sorted chronologically, a sorting method by the dateTime index is called to ensure everything is correct.
btc_data_daily = btc_data_daily.sort_index()

# %%
# Check for null values in the original set
btc_data.isnull().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
# Check for null values in the resampled dataset
btc_data_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5037 entries, 2012-01-01 to 2025-10-15
# Freq: D
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5037 non-null   float64
#  1   High    5037 non-null   float64
#  2   Low     5037 non-null   float64
#  3   Close   5037 non-null   float64
#  4   Volume  5037 non-null   float64
# dtypes: float64(5)
# memory usage: 236.1 KB

# %% [markdown]
# - There are no null values which is due to the fact that all the data has been fetched from a reliable API.
# - The feature types are also appropriate.

# %% [markdown]
# ### Columns

# %% [markdown]
# <b>A short description of the features (a standard stock measurement; also called OHLCV): </b>
# - Open --> the price of BTC when the day started (<= High and >= Low)
# - High --> the highest price of BTC in the mentioned day (the highest value for the day)
# - Low --> the lowest price of BTC in the mentioned day (the lowest value for the day)
# - Close --> the price of BTC when the day ended (<= High and >= Low)
# - Volume --> the total amount of BTC which were traded
#
# <b>Features to be Added:</b>
# - RSI -->
# - other -->

# %% [markdown]
# ## EDA - Exploratory Data Analysis

# %%
# a line chart showing the ups and downs
# box plots for all features
# correlation between the features
# when are the price peaks

# %%
btc_data_daily
# Out:
#                  Open       High        Low      Close       Volume
# Timestamp
# 2012-01-01       4.58       4.84       4.58       4.84    10.000000
# 2012-01-02       4.84       5.00       4.84       5.00    10.100000
# 2012-01-03       5.00       5.32       5.00       5.29   107.085281
# 2012-01-04       5.29       5.57       4.93       5.57   107.233260
# 2012-01-05       5.57       6.46       5.57       6.42    70.328742
# ...               ...        ...        ...        ...          ...
# 2025-10-11  112989.00  113444.00  109711.00  110764.00  2954.913907
# 2025-10-12  110769.00  115854.00  109711.00  115090.00  2969.343862
# 2025-10-13  115089.00  116035.00  113751.00  115265.00  1947.580681
# 2025-10-14  115275.00  115508.00  109971.00  113078.00  2253.667329
# 2025-10-15  113077.00  113655.00  110217.00  110763.00  2021.923209
#
# [5037 rows x 5 columns]

# %%
# Plot for visualizing the price trend
plt.figure(figsize = (15, 5))
plt.plot(btc_data_daily['Close'], label = 'Close Price')

plt.title('Bitcoin Close price', fontsize = 15)
plt.xlabel('Date')
plt.ylabel('Price in dollars')
plt.grid(True)
plt.legend()

# the code below use dates module of matplotlib (included in the imports in the beginning of the article)
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# An upward trend can be noticed from this chart. BTC started with a price near the 0 in 2012 (only 4 US dollars) and nowadays it is about $120,000. According to the line chart above the steepest increase is in 2021. However, there are some dips in the price especially in 2022.

# %%
# Let's plot some barplots to see the details

# %%
btc_data_daily.describe()
# Out:
#                 Open           High            Low          Close  \
# count    5037.000000    5037.000000    5037.000000    5037.000000
# mean    20514.790264   20963.849605   20047.129545   20536.673609
# std     29044.821199   29568.147048   28495.696903   29071.074500
# min         4.380000       4.380000       3.800000       4.380000
# 25%       439.200000     449.000000     428.420000     439.860000
# 50%      7160.000000    7354.100000    6922.070000    7162.050000
# 75%     30039.900000   30505.140000   29377.000000   30047.000000
# max    124728.000000  126272.000000  123148.000000  124728.000000
#
#               Volume
# count    5037.000000
# mean     7426.478889
# std      9025.350288
# min         0.000000
# 25%      1983.421478
# 50%      4508.774920
# 75%      9582.988310
# max    127286.486533

# %% [markdown]
# Conclusion from the describe method:
# OHLC values range from 4 - 123+k which is a huge range. The median is approx. 7000 and it is closer to the minimum and far from the maximum. As a result, the distribution histograms are expected to be right-skewed. This means that BTC had a huge increase for a short period of time.

# %%
# Distribution of the values Open, High, Low, Close
features = ['Open', 'High', 'Low', 'Close']
fig, axes = plt.subplots(2, 2, figsize = (15, 10))
for i, col in enumerate(features):
    row = i // 2
    col_idx = i % 2
    ax1 = axes[row, col_idx]

    # Histogram on primary y-axis
    sn.histplot(btc_data_daily[col], bins=20, ax=ax1, color='skyblue')
    ax1.set_xlabel(col)
    ax1.set_ylabel('Day Count in Price Range', color='blue')
    ax1.tick_params(axis='y', labelcolor='blue')

    # KDE on secondary y-axis
    ax2 = ax1.twinx()
    sn.kdeplot(btc_data_daily[col], ax=ax2, color='red', linewidth=2)
    ax2.set_ylabel('Density', color='red')
    ax2.tick_params(axis='y', labelcolor='red')

    ax1.set_title(f'{col} Distribution')

plt.tight_layout()
plt.show()

# %%
# Distribution of ['Volume']
sn.histplot(np.log1p(btc_data_daily['Volume']), bins=20, color='skyblue')
plt.ylabel('Day Count in Price Range')
plt.tight_layout()
plt.show()

# %% [markdown]
# The volume is at its lowest at the beginning of BTC which is absolutely normal. After that there is a huge increase. The distribution is a little bit left-skewed. Without this left tail the distribution would have been similar to the Gaussian distribution.

# %%
# Visualize box plots to see the outliers
plt.subplots(2, 2, figsize = (20, 10))
for i, col in enumerate(features):
    plt.subplot(2, 2, i + 1)
    sn.boxplot(btc_data_daily[col], orient = 'h')
plt.tight_layout()
plt.show()

# %% [markdown]
# The boxplots above show the presence of a great amount of outliers which is because of the big jump in BTC price.

# %%
corr = btc_data_daily[['Open','High','Low','Close','Volume']].corr()
sn.heatmap(corr, annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# All OHLC features have certain correlation. However, volume and the other features show weak negative correlation but does not mean that the volume decreases when the other features go up. Actually, volume is actually almost independent. However, let's perform a quick Pearson test to see the p-value and if those conclusions are right.

# %%
x_raw = btc_data_daily['Volume']
y_raw = btc_data_daily['Close']

plt.figure(figsize=(14, 5))  # <-- wider figure (14 inches wide, 5 inches tall)

# Raw data
plt.subplot(1, 2, 1)
plt.scatter(x_raw, y_raw, color='red', alpha=0.5)
plt.title('Raw Data')
plt.xlabel('Volume')
plt.ylabel('Close')

# Log-transformed
x_log = np.log1p(x_raw)
y_log = np.log1p(y_raw)

plt.subplot(1, 2, 2)
plt.scatter(x_log, y_log, color='blue', alpha=0.5)
plt.title('Log-Transformed Data')
plt.xlabel('log(Volume)')
plt.ylabel('log(Close)')

plt.tight_layout()
plt.show()

# %% [markdown]
# The scatter plots show that both features do not have linear relationship. After log transformation, the relationship appears more structured and monotonic, meaning that changes in volume and price may have a nonlinear dependency. Most observations are concentrated near the lower left end in the first scatter plot.

# %%
# import scipy.stats as stats

corr, pval = stats.pearsonr(btc_data_daily['Close'], btc_data_daily['Volume'])
print(corr, pval)
# Out:
# -0.32611512930143266 3.97729465135637e-125

# %% [markdown]
# The p-value is a really small number ≈ 3.98 * 10^(-125), which is smaller than the border of 0.05. This means that the negative correlation with the other features is not random but is statistically significant. Nevertheless, the magnitude (≈ -0.33) means that the relationship is weak so no predictions can be performed. BUT from the histogram above it can be seen that the features are not normally distributed so Pearson's R test might not be appropriate here. Moreover, data has a lot of outliers.
# Some more methods will be tried:
# - Spearman's R - for non-normal, non-linear data with outliers
# - Kendall's Tau - better for small datasets
# - Mutual Information - capturing nonlinear and non-monotonic relationships — e.g., when Volume spikes both during price rises and drops

# %%
# from scipy.stats import spearmanr

rho, pval = spearmanr(btc_data_daily['Close'], btc_data_daily['Volume'])
print(rho, pval)
# Out:
# -0.35463013026822987 3.569461900341037e-149

# %%
# from scipy.stats import kendalltau

tau, pval = kendalltau(btc_data_daily['Close'], btc_data_daily['Volume'])
print(tau, pval)
# Out:
# -0.25095437532288095 3.95799210597245e-157

# %%
# from sklearn.feature_selection import mutual_info_regression

X = btc_data_daily[['Volume']].values
y = btc_data_daily['Close'].values
mi = mutual_info_regression(X, y)
print(mi)
# Out:
# [0.43607075]

# %% [markdown]
# All other methods mentioned and performed above approve the result from the Pearson's test.

# %% [markdown]
# While Volume and Close are not linearly correlated, there may be a nonlinear or regime-dependent relationship (e.g., volume spikes during both strong rallies and crashes).
#
# Therefore, Volume might not be a good direct predictor of price, but it could be useful as a secondary or interaction feature — especially when combined with volatility, momentum, or lagged returns.
#
# The features Volume and Close show a statistically significant but weak negative correlation. Their relationship is nonlinear and non-Gaussian, meaning traditional linear correlation (Pearson) underrepresents their dependency. Log-transformed or rank-based methods (e.g., Spearman, mutual information) better capture their behavior.

# %% [markdown]
# ## Feature Engineering
#
# - **Relative Strength Index (RSI)** |
#   **Type:** Oscillator |
#   **Sub-type:** Leading indicator |
#   **Concerned with:** Momentum

# %%
def count_null_values(features):   
    print("Count of null values:")
    print()
    for col in features:
        print(f"{col}: {df[col].isna().sum()}")
        print('------------------')

# %% [markdown]
# **Formula**:
# <br>
# RSI = 100 - [100 / (1 + RS)]
# Where: RS (Relative Strength) = Average Gain / Average Loss

# %%
df = btc_data_daily
df['RSI_14'] = ta.rsi(df['Close'], length=14)

# %%
df
# Out:
#                  Open       High        Low      Close       Volume  \
# Timestamp
# 2012-01-01       4.58       4.84       4.58       4.84    10.000000
# 2012-01-02       4.84       5.00       4.84       5.00    10.100000
# 2012-01-03       5.00       5.32       5.00       5.29   107.085281
# 2012-01-04       5.29       5.57       4.93       5.57   107.233260
# 2012-01-05       5.57       6.46       5.57       6.42    70.328742
# ...               ...        ...        ...        ...          ...
# 2025-10-11  112989.00  113444.00  109711.00  110764.00  2954.913907
# 2025-10-12  110769.00  115854.00  109711.00  115090.00  2969.343862
# 2025-10-13  115089.00  116035.00  113751.00  115265.00  1947.580681
# 2025-10-14  115275.00  115508.00  109971.00  113078.00  2253.667329
# 2025-10-15  113077.00  113655.00  110217.00  110763.00  2021.923209
#
#                 RSI_14
# Timestamp
# 2012-01-01         NaN
# 2012-01-02  100.000000
# 2012-01-03  100.000000
# 2012-01-04  100.000000
# 2012-01-05  100.000000
# ...                ...
# 2025-10-11   38.851085
# 2025-10-12   47.248783
# 2025-10-13   47.562508
# 2025-10-14   44.037687
# 2025-10-15   40.607153
#
# [5037 rows x 6 columns]

# %%
df[df["RSI_14"].isna()]
# Out:
#             Open  High   Low  Close  Volume  RSI_14
# Timestamp
# 2012-01-01  4.58  4.84  4.58   4.84    10.0     NaN

# %%
# Replace the NaN of the first day in which BTC was available with 0
df.RSI_14 = df.RSI_14.fillna(0)

# %%
# df.drop(columns = "RSI", inplace = True)

# %%
df.RSI_14 = df.RSI_14.round(2)

# %% [markdown]
# - **Moving Average Convergence Divergence (MACD)** |
#   **Type:** Oscillator |
#   **Sub-type:** Lagging indicator |
#   **Concerned with:** Momentum

# %%
df.ta.macd(close='Close', fast=12, slow=26, signal=9, append=True)
# Out:
#             MACD_12_26_9  MACDh_12_26_9  MACDs_12_26_9
# Timestamp
# 2012-01-01           NaN            NaN            NaN
# 2012-01-02           NaN            NaN            NaN
# 2012-01-03           NaN            NaN            NaN
# 2012-01-04           NaN            NaN            NaN
# 2012-01-05           NaN            NaN            NaN
# ...                  ...            ...            ...
# 2025-10-11    959.676817    -676.723408    1636.400226
# 2025-10-12    668.459266    -774.352768    1442.812034
# 2025-10-13    446.639710    -796.937859    1243.577569
# 2025-10-14     93.298011    -920.223646    1013.521657
# 2025-10-15   -369.272244   -1106.235121     736.962877
#
# [5037 rows x 3 columns]

# %%
macd_features = ['MACD_12_26_9', 'MACDh_12_26_9', 'MACDs_12_26_9']
count_null_values(macd_features)
# Out:
# Count of null values:
#
# MACD_12_26_9: 25
# ------------------
# MACDh_12_26_9: 33
# ------------------
# MACDs_12_26_9: 33
# ------------------

# %% [markdown]
# The null values will be replaced with 0 because there are no data.

# %%
df[macd_features] = df[macd_features].fillna(0)
df[macd_features] = df[macd_features].round(2)

# %%
df[macd_features]
# Out:
#             MACD_12_26_9  MACDh_12_26_9  MACDs_12_26_9
# Timestamp
# 2012-01-01          0.00           0.00           0.00
# 2012-01-02          0.00           0.00           0.00
# 2012-01-03          0.00           0.00           0.00
# 2012-01-04          0.00           0.00           0.00
# 2012-01-05          0.00           0.00           0.00
# ...                  ...            ...            ...
# 2025-10-11        959.68        -676.72        1636.40
# 2025-10-12        668.46        -774.35        1442.81
# 2025-10-13        446.64        -796.94        1243.58
# 2025-10-14         93.30        -920.22        1013.52
# 2025-10-15       -369.27       -1106.24         736.96
#
# [5037 rows x 3 columns]

# %% [markdown]
# - **Bollinger Bands** |
#   **Type:** Overlay |
#   **Sub-type:** Lagging indicator |
#   **Concerned with:** Volatility

# %%
df.ta.bbands(close='Close', length=20, std=2, append=True)
# Out:
#             BBL_20_2.0_2.0  BBM_20_2.0_2.0  BBU_20_2.0_2.0  BBB_20_2.0_2.0  \
# Timestamp
# 2012-01-01             NaN             NaN             NaN             NaN
# 2012-01-02             NaN             NaN             NaN             NaN
# 2012-01-03             NaN             NaN             NaN             NaN
# 2012-01-04             NaN             NaN             NaN             NaN
# 2012-01-05             NaN             NaN             NaN             NaN
# ...                    ...             ...             ...             ...
# 2025-10-11   105503.704761       116480.95   127458.195239       18.848138
# 2025-10-12   105740.017715       116598.40   127456.782285       18.625268
# 2025-10-13   106094.336742       116760.40   127426.463258       18.270001
# 2025-10-14   106063.037973       116747.35   127431.662027       18.303305
# 2025-10-15   106389.625354       116834.45   127279.274646       17.879700
#
#             BBP_20_2.0_2.0
# Timestamp
# 2012-01-01             NaN
# 2012-01-02             NaN
# 2012-01-03             NaN
# 2012-01-04             NaN
# 2012-01-05             NaN
# ...                    ...
# 2025-10-11        0.239600
# 2025-10-12        0.430542
# 2025-10-13        0.429899
# 2025-10-14        0.328283
# 2025-10-15        0.209356
#
# [5037 rows x 5 columns]

# %%
bb_features = ['BBL_20_2.0_2.0', 'BBM_20_2.0_2.0', 'BBU_20_2.0_2.0', 'BBB_20_2.0_2.0', 'BBP_20_2.0_2.0']
count_null_values(bb_features)
# Out:
# Count of null values:
#
# BBL_20_2.0_2.0: 19
# ------------------
# BBM_20_2.0_2.0: 19
# ------------------
# BBU_20_2.0_2.0: 19
# ------------------
# BBB_20_2.0_2.0: 19
# ------------------
# BBP_20_2.0_2.0: 19
# ------------------

# %%
df[bb_features] = df[bb_features].fillna(0)
df[bb_features] = df[bb_features].round(2)
df[bb_features]
# Out:
#             BBL_20_2.0_2.0  BBM_20_2.0_2.0  BBU_20_2.0_2.0  BBB_20_2.0_2.0  \
# Timestamp
# 2012-01-01            0.00            0.00            0.00            0.00
# 2012-01-02            0.00            0.00            0.00            0.00
# 2012-01-03            0.00            0.00            0.00            0.00
# 2012-01-04            0.00            0.00            0.00            0.00
# 2012-01-05            0.00            0.00            0.00            0.00
# ...                    ...             ...             ...             ...
# 2025-10-11       105503.70       116480.95       127458.20           18.85
# 2025-10-12       105740.02       116598.40       127456.78           18.63
# 2025-10-13       106094.34       116760.40       127426.46           18.27
# 2025-10-14       106063.04       116747.35       127431.66           18.30
# 2025-10-15       106389.63       116834.45       127279.27           17.88
#
#             BBP_20_2.0_2.0
# Timestamp
# 2012-01-01            0.00
# 2012-01-02            0.00
# 2012-01-03            0.00
# 2012-01-04            0.00
# 2012-01-05            0.00
# ...                    ...
# 2025-10-11            0.24
# 2025-10-12            0.43
# 2025-10-13            0.43
# 2025-10-14            0.33
# 2025-10-15            0.21
#
# [5037 rows x 5 columns]

# %% [markdown]
# - **Moving Averages (MAs)** |
#   **Type:** Overlay |
#   **Sub-type:** Lagging indicator |
#   **Concerned with:** Trend

# %%
df.ta.sma(length=20, append=True)  # 20-day SMA
df.ta.sma(length=50, append=True)  # 50-day SMA
df.ta.sma(length=200, append=True) # 200-day SMA (long-term trend)

# Exponential Moving Averages
df.ta.ema(length=12, append=True)
df.ta.ema(length=26, append=True)
# Out:
# Timestamp
# 2012-01-01              NaN
# 2012-01-02              NaN
# 2012-01-03              NaN
# 2012-01-04              NaN
# 2012-01-05              NaN
#                   ...
# 2025-10-11    116889.814736
# 2025-10-12    116756.495126
# 2025-10-13    116646.014005
# 2025-10-14    116381.716672
# 2025-10-15    115965.515437
# Freq: D, Name: EMA_26, Length: 5037, dtype: float64

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'RSI_14', 'MACD_12_26_9',
#        'MACDh_12_26_9', 'MACDs_12_26_9', 'BBL_20_2.0_2.0', 'BBM_20_2.0_2.0',
#        'BBU_20_2.0_2.0', 'BBB_20_2.0_2.0', 'BBP_20_2.0_2.0', 'SMA_20',
#        'SMA_50', 'SMA_200', 'EMA_12', 'EMA_26'],
#       dtype='object')

# %%
ma_features = ['SMA_20', 'SMA_50', 'SMA_200', 'EMA_12', 'EMA_26']

# %%
count_null_values(ma_features)
# Out:
# Count of null values:
#
# SMA_20: 19
# ------------------
# SMA_50: 49
# ------------------
# SMA_200: 199
# ------------------
# EMA_12: 11
# ------------------
# EMA_26: 25
# ------------------

# %%
df[ma_features] = df[ma_features].fillna(0)
df[ma_features] = df[ma_features].round(2)

# %%
df[ma_features].tail(10)
# Out:
#                SMA_20     SMA_50    SMA_200     EMA_12     EMA_26
# Timestamp
# 2025-10-06  115988.95  114009.50  105907.13  119017.17  116582.43
# 2025-10-07  116234.85  114112.10  106093.80  119382.99  116938.91
# 2025-10-08  116545.85  114321.60  106291.41  119992.53  117413.44
# 2025-10-09  116845.50  114470.24  106469.47  120254.45  117730.59
# 2025-10-10  116707.35  114480.72  106596.88  119137.76  117379.88
# 2025-10-11  116480.95  114358.18  106713.52  117849.49  116889.81
# 2025-10-12  116598.40  114352.14  106854.41  117424.95  116756.50
# 2025-10-13  116760.40  114387.88  106994.64  117092.65  116646.01
# 2025-10-14  116747.35  114446.72  107138.14  116475.01  116381.72
# 2025-10-15  116834.45  114426.22  107278.91  115596.24  115965.52

# %% [markdown]
# - **Accelerator Oscillator** |
#   **Type:** Oscillator |
#   **Sub-type:** Leading indicator |
#   **Concerned with:** Momentum

# %%
df.ta.ao(high='High', low='Low', append=True)
# Out:
# Timestamp
# 2012-01-01            NaN
# 2012-01-02            NaN
# 2012-01-03            NaN
# 2012-01-04            NaN
# 2012-01-05            NaN
#                  ...
# 2025-10-11    3117.717647
# 2025-10-12    1056.417647
# 2025-10-13    -582.679412
# 2025-10-14   -2393.205882
# 2025-10-15   -3157.197059
# Freq: D, Name: AO_5_34, Length: 5037, dtype: float64

# %%
df['AO_5_34'].isna().sum()
# Out:
# np.int64(33)

# %%
df['AO_5_34'] = df['AO_5_34'].fillna(0).round(2)

# %% [markdown]
# - **Stochastic** |
#   **Type:** Oscillator |
#   **Sub-type:** Leading indicator |
#   **Concerned with:** Momentum

# %%
df.ta.stoch(high='High', low='Low', k=14, d=3, append=True)
# Out:
#             STOCHk_14_3_3  STOCHd_14_3_3  STOCHh_14_3_3
# Timestamp
# 2012-01-01            NaN            NaN            NaN
# 2012-01-02            NaN            NaN            NaN
# 2012-01-03            NaN            NaN            NaN
# 2012-01-04            NaN            NaN            NaN
# 2012-01-05            NaN            NaN            NaN
# ...                   ...            ...            ...
# 2025-10-11      35.164803      57.235737     -22.070934
# 2025-10-12      21.366630      38.835966     -17.469336
# 2025-10-13      25.065300      27.198911      -2.133611
# 2025-10-14      28.902687      25.111539       3.791148
# 2025-10-15      20.208170      24.725385      -4.517215
#
# [5037 rows x 3 columns]

# %%
stoch_features = ['STOCHk_14_3_3', 'STOCHd_14_3_3', 'STOCHh_14_3_3']
count_null_values(stoch_features)
# Out:
# Count of null values:
#
# STOCHk_14_3_3: 15
# ------------------
# STOCHd_14_3_3: 17
# ------------------
# STOCHh_14_3_3: 17
# ------------------

# %%
df[stoch_features] = df[stoch_features].fillna(0).round(2)

# %%
df.sample(10)
# Out:
#                 Open      High       Low     Close        Volume  RSI_14  \
# Timestamp
# 2015-04-06    256.97    262.98    254.65    255.00   6440.461076   48.70
# 2019-08-24  10425.00  10454.31   9885.48  10103.85   5095.793352   44.01
# 2024-04-06  67412.00  68495.00  67378.00  68280.00    655.487299   53.28
# 2023-09-01  26147.00  26188.00  25333.00  25622.00   2361.748225   36.63
# 2016-08-06    574.45    588.65    562.56    582.96   6038.943967   34.82
# 2018-07-17   6674.96   7468.31   6641.35   7295.13  12282.324003   66.07
# 2014-01-30    799.17    812.44    770.70    803.11  12597.660181   49.77
# 2014-02-13    666.00    667.43    631.00    634.04  16707.809273   25.65
# 2019-11-19   8181.17   8231.40   7989.15   8088.86   4691.175213   35.38
# 2012-02-01      5.55      6.00      3.80      5.99     13.552446   51.24
#
#             MACD_12_26_9  MACDh_12_26_9  MACDs_12_26_9  BBL_20_2.0_2.0  ...  \
# Timestamp                                                               ...
# 2015-04-06         -3.22           0.48          -3.70          238.67  ...
# 2019-08-24       -120.55         -82.32         -38.24         9525.30  ...
# 2024-04-06       1011.58        -504.29        1515.87        62998.40  ...
# 2023-09-01       -682.02          46.25        -728.27        24257.83  ...
# 2016-08-06        -21.48          -9.09         -12.39          554.03  ...
# 2018-07-17         -6.00          87.31         -93.30         5855.88  ...
# 2014-01-30          1.97          -4.73           6.70          769.63  ...
# 2014-02-13        -38.38         -17.04         -21.33          634.43  ...
# 2019-11-19       -132.00        -109.20         -22.80         8084.47  ...
# 2012-02-01         -0.18           0.00           0.00            5.12  ...
#
#             BBP_20_2.0_2.0    SMA_20    SMA_50   SMA_200    EMA_12    EMA_26  \
# Timestamp
# 2015-04-06            0.55    253.52    259.66    309.07    253.41    256.63
# 2019-08-24            0.22  10851.82  10693.08   7291.25  10441.92  10562.47
# 2024-04-06            0.57  67668.95  63991.16  44504.38  68105.55  67093.97
# 2023-09-01            0.26  26927.45  28473.30  27525.52  26546.41  27228.43
# 2016-08-06            0.18    633.44    651.82    498.06    604.52    626.00
# 2018-07-17            1.18   6463.87   6732.27   8907.50   6558.78   6564.77
# 2014-01-30            0.35    817.73    777.67    392.25    806.95    804.97
# 2014-02-13           -0.00    762.15    787.26    438.15    713.64    752.02
# 2019-11-19            0.00   8863.07   8563.75   9348.97   8556.95   8688.95
# 2012-02-01            0.35      6.37      0.00      0.00      5.98      6.16
#
#             AO_5_34  STOCHk_14_3_3  STOCHd_14_3_3  STOCHh_14_3_3
# Timestamp
# 2015-04-06   -11.37          53.97          50.87           3.10
# 2019-08-24  -193.99          31.57          31.35           0.22
# 2024-04-06  -753.59          58.58          53.59           5.00
# 2023-09-01 -1327.42          29.57          40.00         -10.42
# 2016-08-06   -78.75          53.89          46.67           7.22
# 2018-07-17    30.79          69.04          49.95          19.09
# 2014-01-30   -13.42          60.89          54.76           6.13
# 2014-02-13  -119.31          42.45          43.75          -1.29
# 2019-11-19  -328.17          10.55          10.83          -0.29
# 2012-02-01     0.00          57.78          54.75           3.03
#
# [10 rows x 23 columns]

# %% [markdown]
# A quick check for correlated columns will be done to see if there are some unnecessary features.

# %%
corr_matrix = df.corr()

plt.figure(figsize=(18, 10))
sn.heatmap(corr_matrix, cmap='coolwarm', annot=False)
plt.title("Feature Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 10))

sn.heatmap(df.corr() > 0.9, annot=True, cbar=False)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# As it can be seen from the heatmaps above, there are some features which correlate strongly with the OHLC features such as the Moving Averages and the Bollinger Bands. These columns removal will be considered.

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'RSI_14', 'MACD_12_26_9',
#        'MACDh_12_26_9', 'MACDs_12_26_9', 'BBL_20_2.0_2.0', 'BBM_20_2.0_2.0',
#        'BBU_20_2.0_2.0', 'BBB_20_2.0_2.0', 'BBP_20_2.0_2.0', 'SMA_20',
#        'SMA_50', 'SMA_200', 'EMA_12', 'EMA_26', 'AO_5_34', 'STOCHk_14_3_3',
#        'STOCHd_14_3_3', 'STOCHh_14_3_3'],
#       dtype='object')

# %% [markdown]
# I will remove the highly correlated columns such as SMA and EMA and also the Bollinger Bands.

# %%
remove_cols = df.columns[
    df.columns.str.startswith('BB') |
    df.columns.str.startswith('EMA') |
    df.columns.str.startswith('SMA')
]

# %%
remove_cols
# Out:
# Index(['BBL_20_2.0_2.0', 'BBM_20_2.0_2.0', 'BBU_20_2.0_2.0', 'BBB_20_2.0_2.0',
#        'BBP_20_2.0_2.0', 'SMA_20', 'SMA_50', 'SMA_200', 'EMA_12', 'EMA_26'],
#       dtype='object')

# %%
df = df.drop(columns = remove_cols)

# %%
high_corr_cols = df[(df.corr() > 0.9)]

# %%
high_corr_cols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5037 entries, 2012-01-01 to 2025-10-15
# Freq: D
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Open            0 non-null      float64
#  1   High            0 non-null      float64
#  2   Low             0 non-null      float64
#  3   Close           0 non-null      float64
#  4   Volume          0 non-null      float64
#  5   RSI_14          0 non-null      float64
#  6   MACD_12_26_9    0 non-null      float64
#  7   MACDh_12_26_9   0 non-null      float64
#  8   MACDs_12_26_9   0 non-null      float64
#  9   BBL_20_2.0_2.0  0 non-null      float64
#  10  BBM_20_2.0_2.0  0 non-null      float64
#  11  BBU_20_2.0_2.0  0 non-null      float64
#  12  BBB_20_2.0_2.0  0 non-null      float64
#  13  BBP_20_2.0_2.0  0 non-null      float64
#  14  SMA_20          0 non-null      float64
#  15  SMA_50          0 non-null      float64
#  16  SMA_200         0 non-null      float64
#  17  EMA_12          0 non-null      float64
#  18  EMA_26          0 non-null      float64
#  19  AO_5_34         0 non-null      float64
#  20  STOCHk_14_3_3   0 non-null      float64
#  21  STOCHd_14_3_3   0 non-null      float64
#  22  STOCHh_14_3_3   0 non-null      float64
# dtypes: float64(23)
# memory usage: 1.0 MB

# %%
n = len(df)
train_size = int(n * 0.7)
val_size = int(n * 0.15)
test_size = n - train_size - val_size

train = df.iloc[:train_size]
val = df.iloc[train_size:train_size + val_size]
test = df.iloc[train_size + val_size:]

# %%
df['Target'] = df['Close'].shift(-1)
df.dropna(inplace=True)

# %%
features = df.drop(columns = 'Target').columns.tolist()

# %%
features
# Out:
# ['Open',
#  'High',
#  'Low',
#  'Close',
#  'Volume',
#  'RSI_14',
#  'MACD_12_26_9',
#  'MACDh_12_26_9',
#  'MACDs_12_26_9',
#  'AO_5_34',
#  'STOCHk_14_3_3',
#  'STOCHd_14_3_3',
#  'STOCHh_14_3_3']

# %%
attributes = df[features]

# %%
target = df.Target

# %%
x_train = attributes.iloc[:train_size]
y_train = target.iloc[:train_size]

# %%
x_val = attributes.iloc[train_size:train_size + val_size]
y_val = target.iloc[train_size:train_size + val_size]

# %%
x_test = attributes.iloc[train_size + val_size:]
y_test = target.iloc[train_size + val_size:]

# %%
#### Scaling
scaler = MinMaxScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_val_scaled = scaler.transform(x_val)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# Fit_transform is performed on the training data separately in order to prevent data leakage.

# %%
x_test
# Out:
#                 Open      High       Low     Close       Volume  RSI_14  \
# Timestamp
# 2023-09-20   27198.0   27389.0   26852.0   26945.0  2285.385328   54.65
# 2023-09-21   26950.0   27235.0   26376.0   26602.0  1464.104898   50.55
# 2023-09-22   26588.0   26733.0   26479.0   26536.0   974.488762   49.78
# 2023-09-23   26542.0   26634.0   26493.0   26613.0   298.984232   50.72
# 2023-09-24   26613.0   26730.0   26359.0   26458.0   565.132167   48.73
# ...              ...       ...       ...       ...          ...     ...
# 2025-10-10  121695.0  122582.0  109683.0  112996.0  4713.818945   42.06
# 2025-10-11  112989.0  113444.0  109711.0  110764.0  2954.913907   38.85
# 2025-10-12  110769.0  115854.0  109711.0  115090.0  2969.343862   47.25
# 2025-10-13  115089.0  116035.0  113751.0  115265.0  1947.580681   47.56
# 2025-10-14  115275.0  115508.0  109971.0  113078.0  2253.667329   44.04
#
#             MACD_12_26_9  MACDh_12_26_9  MACDs_12_26_9  BBL_20_2.0_2.0  ...  \
# Timestamp                                                               ...
# 2023-09-20        -11.72         215.61        -227.33        25053.89  ...
# 2023-09-21         -4.55         178.23        -182.77        25109.71  ...
# 2023-09-22         -4.14         142.91        -147.05        25145.16  ...
# 2023-09-23          2.37         119.53        -117.17        25165.41  ...
# 2023-09-24         -4.93          89.79         -94.72        25202.99  ...
# ...                  ...            ...            ...             ...  ...
# 2025-10-10       1757.88         -47.70        1805.58       106044.29  ...
# 2025-10-11        959.68        -676.72        1636.40       105503.70  ...
# 2025-10-12        668.46        -774.35        1442.81       105740.02  ...
# 2025-10-13        446.64        -796.94        1243.58       106094.34  ...
# 2025-10-14         93.30        -920.22        1013.52       106063.04  ...
#
#             BBP_20_2.0_2.0     SMA_20     SMA_50    SMA_200     EMA_12  \
# Timestamp
# 2023-09-20            0.88   26122.75   27148.40   27765.30   26522.99
# 2023-09-21            0.70   26171.75   27097.72   27786.13   26535.14
# 2023-09-22            0.66   26206.75   27043.24   27806.29   26535.27
# 2023-09-23            0.68   26237.30   26995.78   27828.35   26547.23
# 2023-09-24            0.59   26265.90   26944.20   27850.54   26533.50
# ...                    ...        ...        ...        ...        ...
# 2025-10-10            0.33  116707.35  114480.72  106596.88  119137.76
# 2025-10-11            0.24  116480.95  114358.18  106713.52  117849.49
# 2025-10-12            0.43  116598.40  114352.14  106854.41  117424.95
# 2025-10-13            0.43  116760.40  114387.88  106994.64  117092.65
# 2025-10-14            0.33  116747.35  114446.72  107138.14  116475.01
#
#                EMA_26  AO_5_34  STOCHk_14_3_3  STOCHd_14_3_3  STOCHh_14_3_3
# Timestamp
# 2023-09-20   26534.70   634.78          81.37          81.25           0.12
# 2023-09-21   26539.69   668.34          77.76          80.43          -2.67
# 2023-09-22   26539.42   667.63          69.15          76.09          -6.95
# 2023-09-23   26544.87   586.14          64.84          70.58          -5.75
# 2023-09-24   26538.43   464.06          62.96          65.65          -2.68
# ...               ...      ...            ...            ...            ...
# 2025-10-10  117379.88  5764.01          59.98          72.95         -12.98
# 2025-10-11  116889.81  3117.72          35.16          57.24         -22.07
# 2025-10-12  116756.50  1056.42          21.37          38.84         -17.47
# 2025-10-13  116646.01  -582.68          25.07          27.20          -2.13
# 2025-10-14  116381.72 -2393.21          28.90          25.11           3.79
#
# [756 rows x 23 columns]

# %%
if isinstance(x_test, pd.DataFrame):
    persistence_preds = x_test['Close'].values
else:
    # намери индекса на колоната Close в X (DataFrame с фичъри)
    close_idx = list(X.columns).index('Close')
    persistence_preds = x_test[:, close_idx]

# Увери се, че y_test и persistence_preds са 1D numpy масиви
persistence_preds = np.ravel(persistence_preds)
y_true = np.ravel(y_test)

# Бързи shape-проверки (полезно за дебъг)
print("shapes -> X_test:", getattr(x_test, "shape", None), "y_test:", y_true.shape, "persistence_preds:", persistence_preds.shape)

# --- Метрики ---
mse = mean_squared_error(y_true, persistence_preds)   # MSE (works in all sklearn versions)
rmse = np.sqrt(mse)                                  # RMSE
mae = mean_absolute_error(y_true, persistence_preds)
r2 = r2_score(y_true, persistence_preds)

print("\nPERSISTENCE BASELINE RESULTS:")
print(f"MSE:  {mse:.6f}")
print(f"RMSE: {rmse:.6f}")
print(f"MAE:  {mae:.6f}")
print(f"R²:   {r2:.6f}")
# Out:
# shapes -> X_test: (756, 23) y_test: (756,) persistence_preds: (756,)
#
# PERSISTENCE BASELINE RESULTS:
# MSE:  3441858.764550
# RMSE: 1855.224721
# MAE:  1294.417989
# R²:   0.995193

# %%
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)

y_pred = lin_reg.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("\nLINEAR REGRESSION RESULTS:")
print(f"MSE:  {mse:.6f}")
print(f"RMSE: {rmse:.6f}")
print(f"MAE:  {mae:.6f}")
print(f"R²:   {r2:.6f}")


coefficients = pd.DataFrame({
    'Feature': x_train.columns,
    'Coefficient': lin_reg.coef_
}).sort_values(by='Coefficient', ascending=False)

print("\nTop influential features:")
print(coefficients.head(10))
print("\nLeast influential features:")
print(coefficients.tail(10))
# Out:
# LINEAR REGRESSION RESULTS:
# MSE:  3445061.324130
# RMSE: 1856.087639
# MAE:  1300.204882
# R²:   0.995188
#
# Top influential features:
#            Feature  Coefficient
# 6     MACD_12_26_9   616.902640
# 10  BBM_20_2.0_2.0   183.266073
# 14          SMA_20   183.266073
# 13  BBP_20_2.0_2.0    69.159267
# 17          EMA_12     3.434032
# 3            Close     0.508149
# 22   STOCHh_14_3_3     0.378170
# 1             High     0.221928
# 2              Low     0.174045
# 5           RSI_14     0.089631
#
# Least influential features:
#            Feature  Coefficient
# 12  BBB_20_2.0_2.0    -0.065101
# 15          SMA_50    -0.068039
# 0             Open    -0.136560
# 19         AO_5_34    -0.290728
# 21   STOCHd_14_3_3    -0.354743
# 18          EMA_26    -3.561957
# 11  BBU_20_2.0_2.0  -183.049426
# 9   BBL_20_2.0_2.0  -183.069726
# 7    MACDh_12_26_9  -617.810574
# 8    MACDs_12_26_9  -619.516063

# %%
if isinstance(x_test, pd.DataFrame):
    persistence_preds = x_test['Close'].values
else:
    # намери индекса на колоната Close в X (DataFrame с фичъри)
    close_idx = list(X.columns).index('Close')
    persistence_preds = x_test[:, close_idx]

# Увери се, че y_test и persistence_preds са 1D numpy масиви
persistence_preds = np.ravel(persistence_preds)
y_true = np.ravel(y_test)

# Бързи shape-проверки (полезно за дебъг)
print("shapes -> X_test:", getattr(x_test, "shape", None), "y_test:", y_true.shape, "persistence_preds:", persistence_preds.shape)

# --- Метрики ---
mse = mean_squared_error(y_true, persistence_preds)   # MSE (works in all sklearn versions)
rmse = np.sqrt(mse)                                  # RMSE
mae = mean_absolute_error(y_true, persistence_preds)
r2 = r2_score(y_true, persistence_preds)

print("\nPERSISTENCE BASELINE RESULTS:")
print(f"MSE:  {mse:.6f}")
print(f"RMSE: {rmse:.6f}")
print(f"MAE:  {mae:.6f}")
print(f"R²:   {r2:.6f}")
# Out:
# shapes -> X_test: (755, 13) y_test: (755,) persistence_preds: (755,)
#
# PERSISTENCE BASELINE RESULTS:
# MSE:  3439319.206623
# RMSE: 1854.540160
# MAE:  1293.066225
# R²:   0.995192

# %%
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)

y_pred = lin_reg.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("\nLINEAR REGRESSION RESULTS:")
print(f"MSE:  {mse:.6f}")
print(f"RMSE: {rmse:.6f}")
print(f"MAE:  {mae:.6f}")
print(f"R²:   {r2:.6f}")


coefficients = pd.DataFrame({
    'Feature': x_train.columns,
    'Coefficient': lin_reg.coef_
}).sort_values(by='Coefficient', ascending=False)

print("\nTop influential features:")
print(coefficients.head(10))
print("\nLeast influential features:")
print(coefficients.tail(10))
# Out:
# LINEAR REGRESSION RESULTS:
# MSE:  3430059.364640
# RMSE: 1852.041945
# MAE:  1290.167177
# R²:   0.995205
#
# Top influential features:
#           Feature  Coefficient
# 6    MACD_12_26_9   726.998529
# 12  STOCHh_14_3_3     1.772906
# 5          RSI_14     0.784448
# 3           Close     0.662914
# 1            High     0.229746
# 11  STOCHd_14_3_3     0.178315
# 2             Low     0.160502
# 4          Volume     0.000840
# 0            Open    -0.054658
# 9         AO_5_34    -0.087323
#
# Least influential features:
#           Feature  Coefficient
# 3           Close     0.662914
# 1            High     0.229746
# 11  STOCHd_14_3_3     0.178315
# 2             Low     0.160502
# 4          Volume     0.000840
# 0            Open    -0.054658
# 9         AO_5_34    -0.087323
# 10  STOCHk_14_3_3    -0.239783
# 7   MACDh_12_26_9  -726.667710
# 8   MACDs_12_26_9  -726.761195

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

# --- Обучение на Decision Tree ---
tree_model = DecisionTreeRegressor(
    max_depth=6,        # ограничаваме дълбочината, за да не се overfit-не
    random_state=42
)

tree_model.fit(x_train, y_train)

# --- Прогнози ---
y_pred_tree = tree_model.predict(x_test)

# --- Метрики ---
mse_tree = mean_squared_error(y_test, y_pred_tree)
rmse_tree = np.sqrt(mse_tree)
mae_tree = mean_absolute_error(y_test, y_pred_tree)
r2_tree = r2_score(y_test, y_pred_tree)

print("DECISION TREE REGRESSOR RESULTS:")
print(f"MSE:  {mse_tree:.6f}")
print(f"RMSE: {rmse_tree:.6f}")
print(f"MAE:  {mae_tree:.6f}")
print(f"R²:   {r2_tree:.6f}")
# Out:
# DECISION TREE REGRESSOR RESULTS:
# MSE:  928860808.189968
# RMSE: 30477.217855
# MAE:  22136.046289
# R²:   -0.298571

# %%
# --- Важност на feature-и ---
importances = pd.DataFrame({
    'Feature': x_train.columns,
    'Importance': tree_model.feature_importances_
}).sort_values(by='Importance', ascending=False)

print("\nTop 10 most important features:")
print(importances.head(10))
# Out:
# Top 10 most important features:
#           Feature  Importance
# 2             Low    0.859578
# 3           Close    0.136635
# 0            Open    0.003074
# 1            High    0.000180
# 10  STOCHk_14_3_3    0.000158
# 5          RSI_14    0.000148
# 8   MACDs_12_26_9    0.000116
# 6    MACD_12_26_9    0.000051
# 9         AO_5_34    0.000036
# 4          Volume    0.000025

# %%
tree_model = DecisionTreeRegressor(
    max_depth=4,            # по-малка дълбочина за по-добра генерализация
    min_samples_split=50,   # минимален брой наблюдения, за да се раздели възел
    min_samples_leaf=20,    # минимален брой наблюдения в листо
    random_state=42
)

tree_model.fit(x_train, y_train)
y_pred_tree = tree_model.predict(x_test)

mse_tree = mean_squared_error(y_test, y_pred_tree)
rmse_tree = np.sqrt(mse_tree)
mae_tree = mean_absolute_error(y_test, y_pred_tree)
r2_tree = r2_score(y_test, y_pred_tree)

print("TUNED DECISION TREE RESULTS:")
print(f"MSE:  {mse_tree:.6f}")
print(f"RMSE: {rmse_tree:.6f}")
print(f"MAE:  {mae_tree:.6f}")
print(f"R²:   {r2_tree:.6f}")

# Важност на фичърите
importances = pd.DataFrame({
    'Feature': x_train.columns,
    'Importance': tree_model.feature_importances_
}).sort_values(by='Importance', ascending=False)

print("\nTop 10 most important features:")
print(importances.head(10))
# Out:
# TUNED DECISION TREE RESULTS:
# MSE:  928761074.649293
# RMSE: 30475.581613
# MAE:  22148.096225
# R²:   -0.298432
#
# Top 10 most important features:
#          Feature  Importance
# 2            Low    0.862892
# 3          Close    0.134223
# 1           High    0.002885
# 0           Open    0.000000
# 4         Volume    0.000000
# 5         RSI_14    0.000000
# 6   MACD_12_26_9    0.000000
# 7  MACDh_12_26_9    0.000000
# 8  MACDs_12_26_9    0.000000
# 9        AO_5_34    0.000000

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

rf_model = RandomForestRegressor(
    n_estimators=200,      # повече дървета = по-стабилна прогноза
    max_depth=10,          # ограничаваме дълбочината, за да не overfit-ва
    min_samples_split=10,  # колко проби трябва да има, за да се раздели възел
    min_samples_leaf=5,    # минимален брой проби в листо
    random_state=42,
    n_jobs=-1              # използва всички ядра за по-бързо обучение
)

rf_model.fit(x_train, y_train)
y_pred_rf = rf_model.predict(x_test)

mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
mae_rf = mean_absolute_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

print("RANDOM FOREST REGRESSOR RESULTS:")
print(f"MSE:  {mse_rf:.6f}")
print(f"RMSE: {rmse_rf:.6f}")
print(f"MAE:  {mae_rf:.6f}")
print(f"R²:   {r2_rf:.6f}")

# Важност на feature-и
importances = pd.DataFrame({
    'Feature': x_train.columns,
    'Importance': rf_model.feature_importances_
}).sort_values(by='Importance', ascending=False)

print("\nTop 10 most important features:")
print(importances.head(10))
# Out:
# RANDOM FOREST REGRESSOR RESULTS:
# MSE:  902251109.879577
# RMSE: 30037.495067
# MAE:  21497.647868
# R²:   -0.261370
#
# Top 10 most important features:
#           Feature  Importance
# 2             Low    0.303324
# 1            High    0.260920
# 3           Close    0.233030
# 0            Open    0.201823
# 10  STOCHk_14_3_3    0.000180
# 5          RSI_14    0.000141
# 12  STOCHh_14_3_3    0.000114
# 8   MACDs_12_26_9    0.000103
# 4          Volume    0.000097
# 11  STOCHd_14_3_3    0.000092
